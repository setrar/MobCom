# %%
using Plots

# %%
L = 20
θ = -0.2
h(t) = [((α >= 0) && (α <= L)) * exp( θ * α) for α in t]

# Define a range for t, assuming it's similar to the Python version
t = 0:1.0:L  # Adjust step size as needed

# Julia's Plots package does not have a direct stem function equivalent as in Matplotlib,
# but we can simulate it using the scatter plot for markers and line plot for stems.
plot(t, h(t), line=(:stem, :blue), label="")
scatter!(t, h(t), marker=:circle, color=:blue, label="h(t)")

# %% [markdown]
# # References
# - [ ] [The Cyclic Prefix for OFDM](https://dspillustrations.com/pages/posts/misc/the-cyclic-prefix-cp-in-ofdm.html)
